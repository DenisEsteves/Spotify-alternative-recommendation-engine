# %%
def user_name():
            print("I will make some cool recommendations!")
            name=input("But first, whats your name?")
            print("Nice to see you!")

def before70():
    import pandas as pd
    import seaborn as sns
    import matplotlib.pyplot as plt
    import numpy as np
    import sklearn
    import random
    import pickle
    from sklearn import cluster
    from sklearn.cluster import KMeans
    from yellowbrick.cluster import KElbowVisualizer
    import spotipy
    from spotipy.oauth2 import SpotifyClientCredentials
    spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials("9c24b7e194394db78e3435d96a43a0d6","264f811e265b44379dcf365b69b1145e"))
    import webbrowser 
    spotifyfull=pd.read_csv(r"C:\Users\Portu\Documents\Ironhack\FP\spotify.csv")
    ccc=spotifyfull.loc[61203]
    c2s=ccc[14]
    ccc=spotifyfull.loc[59724]
    c6s=ccc[14]
    ccc=spotifyfull.loc[8409]
    c7s=ccc[14]
    ccc=spotifyfull.loc[155569]
    c9s=ccc[14]

    print(c2s)
    lz_uri = "spotify:artist:3da4iD3k6GZ7I4yJsGYqCu"


    results = spotify.artist_top_tracks(lz_uri)

    for track in results['tracks'][2:3]:
        print('Play the song: ' + track['preview_url'])
        print('cover art: ' + track['album']['images'][0]['url'])
        print()
    
    print(c6s)
    lz_uri = "spotify:artist:2X9ZzmPwihIKKf2hIFfPyX"


    results = spotify.artist_top_tracks(lz_uri)

    for track in results['tracks'][7:8]:
        print('Play the song: ' + track['preview_url'])
        print('cover art: ' + track['album']['images'][0]['url'])
        print()
    
    
    song170=input("From above, what song do you prefer?")
    while (song170 !=c2s) & (song170 != c6s):
            print("Sorry, not a right answer")
            song170=input("What song do you prefer?")
    if song170== c2s or song170==c6s:
        print("Great!")
        print(c7s)
        lz_uri = "spotify:artist:1FqqOl9itIUpXr4jZPIVoT"


        results = spotify.artist_top_tracks(lz_uri)

        for track in results['tracks'][:1]:
            print('Play the song: ' + track['preview_url'])
            print('cover art: ' + track['album']['images'][0]['url'])
            print()


        print(c9s)
        lz_uri = "spotify:artist:7GtGx0zA35kpwo6z09Vuna"


        results = spotify.artist_top_tracks(lz_uri)

        for track in results['tracks'][2:3]:
            print('Play the song: ' + track['preview_url'])
            print('cover art: ' + track['album']['images'][0]['url'])
            print()          

        song270=input("From above, what song do you prefer?")
        while (song270 != c7s) & (song270 != c9s):
            print("Sorry, not a right answer")
            song270=input("What song do you prefer?")
        if song270==c7s or song270==c9s:
            if song170==c2s:
                if song270==c7s:
                    webbrowser.open("https://open.spotify.com/playlist/3bKLnm3aS8eIHBiYHLjBQe?si=CnYhp1IXRH2QTCld3WpJPQ")
            elif song170==c2s:
                if song270==c9s:
                    webbrowser.open("https://open.spotify.com/playlist/63hIm8Wn76XsoxVHupRBoE?si=wk2m72JSQHKBWTqNFvXYAg")
            if song170==c6s:
                if song270==c7s:
                    webbrowser.open("https://open.spotify.com/playlist/3bKLnm3aS8eIHBiYHLjBQe?si=e-jq-KSBTd29WuOWr-HmiQ")
            elif song170==c6s:
                if song270==c9s:
                    webbrowser.open("https://open.spotify.com/playlist/1jvSwjxasjBn6MBGvYVSBX?si=CoyjTSeKSF2Mx24JbAyhow")
def after70(): 
    import pandas as pd
    import seaborn as sns
    import matplotlib.pyplot as plt
    import numpy as np
    import sklearn
    import random
    import pickle
    from sklearn import cluster
    from sklearn.cluster import KMeans
    from yellowbrick.cluster import KElbowVisualizer
    import spotipy
    from spotipy.oauth2 import SpotifyClientCredentials
    spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials("9c24b7e194394db78e3435d96a43a0d6","264f811e265b44379dcf365b69b1145e"))
    import webbrowser 
    spotifyfull=pd.read_csv(r"C:\Users\Portu\Documents\Ironhack\FP\spotify.csv")
    ccc=spotifyfull.loc[11245]
    c0s=ccc[14]
    ccc=spotifyfull.loc[164087]
    c1s=ccc[14]
    ccc=spotifyfull.loc[28560]
    c4s=ccc[14]
    ccc=spotifyfull.loc[167096]
    c3s=ccc[14]
    ccc=spotifyfull.loc[152207]
    c5s=ccc[14]
    ccc=spotifyfull.loc[168865]
    c8s=ccc[14]
    
    print(c0s)

    lz_uri = "spotify:artist:7tjbDPvrdvDshcpEMXKRVb"


    results = spotify.artist_top_tracks(lz_uri)

    for track in results['tracks'][:1]:
        print('Play the song: ' + track['preview_url'])
        print('cover art: ' + track['album']['images'][0]['url'])
        print()    
    
    print(c1s)
    lz_uri = "spotify:artist:4wM29TDTr3HI0qFY3KoSFG"


    results = spotify.artist_top_tracks(lz_uri)

    for track in results['tracks'][4:5]:
        print('Play the song: ' + track['preview_url'])
        print('cover art: ' + track['album']['images'][0]['url'])
        print()    
    print(c4s)
    lz_uri = "spotify:artist:0cQuYRSzlItquYxsQKDvVc"


    results = spotify.artist_top_tracks(lz_uri)

    for track in results['tracks'][6:7]:
        print('Play the song: ' + track['preview_url'])
        print('cover art: ' + track['album']['images'][0]['url'])
        print()    
    
    song170=input("From these three, what song do you prefer?")
    while (song170 !=c0s) & (song170 != c1s) & (song170 != c4s):
            print("Sorry, not a right answer")
            song170=input("What song do you prefer?")
    if song170==c0s or song170==c1s or song170==c4s:
        print("Great!")
        print(c3s)
        lz_uri = "spotify:artist:3qbnxnvUqR14MJ9g8QwZJK"


        results = spotify.artist_top_tracks(lz_uri)

        for track in results['tracks'][4:5]:
            print('Play the song: ' + track['preview_url'])
            print('cover art: ' + track['album']['images'][0]['url'])
            print()        
        
        print(c5s)
        lz_uri = "spotify:artist:7bhMBjjQhgPX0q9S4Ajncn"


        results = spotify.artist_top_tracks(lz_uri)

        for track in results['tracks'][2:3]:
            print('Play the song: ' + track['preview_url'])
            print('cover art: ' + track['album']['images'][0]['url'])
            print()        
        
        print(c8s)
        lz_uri = "spotify:artist:5RjqSn7vYk8Qb9GeLWRRhB"


        results = spotify.artist_top_tracks(lz_uri)

        for track in results['tracks'][1:2]:
            print('Play the song: ' + track['preview_url'])
            print('cover art: ' + track['album']['images'][0]['url'])
            print()        
        
        song270=input("From these three, what song do you prefer?")
        while (song270 != c3s) & (song270 != c5s) & (song270 != c8s):
            print("Sorry, not a right answer")
            song270=input("What song do you prefer?")
        if song270==c3s or song270==c5s or song270== c8s:
            if song170==c0s:
                if song270==c3s:
                    webbrowser.open("https://open.spotify.com/playlist/25q72nBb5a3vetcC4PI55w?si=ZDFbwwE8TiC7I7fE5Ktrrw")
                    print("You should listen this playlist: https://open.spotify.com/playlist/25q72nBb5a3vetcC4PI55w?si=ZDFbwwE8TiC7I7fE5Ktrrw")
                elif song270==c5s:
                    webbrowser.open("https://open.spotify.com/playlist/24Ftu0obDtxdtm1JPoXUIw?si=ml8KLn-sTK-Vwz8dBixcRw")
                    print("Give it a try: https://open.spotify.com/playlist/24Ftu0obDtxdtm1JPoXUIw?si=ml8KLn-sTK-Vwz8dBixcRw")
                elif song270==c8s:
                    webbrowser.open("https://open.spotify.com/playlist/24Ftu0obDtxdtm1JPoXUIw?si=ml8KLn-sTK-Vwz8dBixcRw")
                    print("You should listen: https://open.spotify.com/playlist/24Ftu0obDtxdtm1JPoXUIw?si=ml8KLn-sTK-Vwz8dBixcRw")
            elif song170==c1s:
                if song270==c3s:
                    webbrowser.open("https://open.spotify.com/playlist/4e542doe5hI3AVTC9X3UOv?si=ThpUq_zcTy6TQlEVyCwHlg")
                    print("I think you may like:https://open.spotify.com/playlist/4e542doe5hI3AVTC9X3UOv?si=ThpUq_zcTy6TQlEVyCwHlg")
                elif song270==c5s:
                    webbrowser.open("https://open.spotify.com/playlist/4e542doe5hI3AVTC9X3UOv?si=ThpUq_zcTy6TQlEVyCwHlg")
                    print("I think you may like:https://open.spotify.com/playlist/4e542doe5hI3AVTC9X3UOv?si=ThpUq_zcTy6TQlEVyCwHlg")
                elif song270==c8s:
                    webbrowser.open("https://open.spotify.com/playlist/4e542doe5hI3AVTC9X3UOv?si=ThpUq_zcTy6TQlEVyCwHlg")
                    print("Give it a try:https://open.spotify.com/playlist/4e542doe5hI3AVTC9X3UOv?si=ThpUq_zcTy6TQlEVyCwHlg")
            elif song170==c4s:
                if song270==c3s:
                    webbrowser.open("https://open.spotify.com/playlist/25q72nBb5a3vetcC4PI55w?si=5Bf1MceiSi-dMO81ThD2Pw")
                    print("You should listen:https://open.spotify.com/playlist/25q72nBb5a3vetcC4PI55w?si=5Bf1MceiSi-dMO81ThD2Pw")
                elif song270==c5s:
                    webbrowser.open("https://open.spotify.com/playlist/25q72nBb5a3vetcC4PI55w?si=fZnhJfqrTZOAfHM6Rtslsg")
                    print("You should like: https://open.spotify.com/playlist/25q72nBb5a3vetcC4PI55w?si=fZnhJfqrTZOAfHM6Rtslsg")
                elif song270==c8s:
                    webbrowser.open("https://open.spotify.com/playlist/24Ftu0obDtxdtm1JPoXUIw?si=CHgrxPy0QOyj3RT3iO0BuQ")
                    print("Pretty sure you will like: https://open.spotify.com/playlist/24Ftu0obDtxdtm1JPoXUIw?si=CHgrxPy0QOyj3RT3iO0BuQ")
 



def choose_decade():
    type_gen=input("Are you interested in music before or after the 70's?")
    while (type_gen != "before") & (type_gen!= "after"):
            print("Sorry,",name," I didn't get you!")
            type_gen=input("Are you interested in music before or after the 70's?")
    if type_gen=="before":
        print("Nice! Those were great times")
        before70()
    elif type_gen=="after":
        print("Ok, generation X!")
        after70()

# %%
def play_game():
    a=input("Hi! So, you are bored and you don't know what music listen to? I am pretty sure I can help you. \nWould you answer me some questions?")
    if a=="yes" or a=="Yes":
        user_name()
        choose_decade()
        
    else:
        print("bye")

# %% [markdown]
# # Spotify Recommendation Engine

# %%
play_game()
